# %%
import matlab.engine
import numpy as np
import pandas as pd
import os

from scipy import optimize
import sklearn.gaussian_process as skg
from scipy.special import erf, erfc
from sklearn.gaussian_process.kernels import RBF, ConstantKernel
import matplotlib.pyplot as plt
from tqdm import tqdm
from numba import jit

import bokeh.io 
from bokeh.plotting import figure, show
from bokeh.layouts import gridplot
from bokeh.transform import linear_cmap
from bokeh.models import LinearColorMapper
bokeh.io.output_notebook()
plt.ioff()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2281">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Define GPA params and visualization function

# %%
lam = 1e-2
l = 0.5
kernel = ConstantKernel(1.0, constant_value_bounds="fixed") * RBF(l, length_scale_bounds="fixed")
gpa = skg.GaussianProcessRegressor(
    alpha=lam,
    kernel=kernel
)

# %%
def viz_gpa(gpa,thresh=False, contour=False, return_contour=False, return_thresh=False):

    x1range = [-1,1]
    x2range = [-1,1]
    dx = 0.01
    alpha = 0.5

    nx1 = int(np.diff(x1range)[0]/dx)
    nx2 = int(np.diff(x2range)[0]/dx)
    
    p = figure(
        x_range=[-1,1],
        y_range=[-1,1],
        match_aspect=True,
        plot_width=600,
        plot_height=600,
    )

    X1grid,X2grid = np.meshgrid(np.arange(*x1range,dx),np.arange(*x2range,dx))
    Xs = np.vstack([X1grid.ravel(), X2grid.ravel()]).transpose()
    # Xs = np.hstack((Xs, np.ones((Xs.shape[0],1))*alpha))

    # print(Xs)

    ys = gpa.predict(Xs).flatten()

    ys = ys.reshape(nx2,nx1)

    # print(ys)

    color_mapper = LinearColorMapper(palette='Viridis256', low=0, high=2)

    if thresh:
        p.image(
            image=[(ys>0).astype(int)],
            x=x1range[0],
            y=x2range[0],
            dw=np.diff(x1range)[0],
            dh=np.diff(x2range)[0],
            color_mapper = color_mapper
        )
    else:
        p.image(
            image=[ys],
            x=x1range[0],
            y=x2range[0],
            dw=np.diff(x1range)[0],
            dh=np.diff(x2range)[0],
            palette='Viridis256'
        )
    if contour:
        plt.ioff()
        c = plt.contour(ys,[0])
        contsegs = c.allsegs[0]
        for cs in contsegs:
            p.line(
                x=cs[:,0]*dx+x1range[0],
                y=cs[:,1]*dx+x2range[0],
                line_width=3,
                color="black"
            )
        # print(contour)
    
    if contour and return_contour:
        return [[cs[:,0]*dx+x1range[0], cs[:,1]*dx+x2range[0]] for cs in contsegs]
    elif return_thresh:
        return (ys>0).astype(int)
    else:
        return p

# %% [markdown]
# # Define ground truth function

# %%
def truth(x):
    x = np.array(x)
    r = np.linalg.norm(x,axis=1,ord=1)
    t = 0.25-np.abs(r-0.5)
    # t += 0.1*(x[:,0] + x[:,1])
    return t

# def truth(x):
#     x = np.array(x)
#     t = 0.1*(x[:,0] + x[:,1])
#     return t

# %%
x0 = -1
dx = 0.01

x1 = np.arange(-1,1,dx)
x2 = np.copy(x1)
X1,X2 = np.meshgrid(x1,x2)

X = np.hstack((
    X1.reshape((-1,1)),
    X2.reshape((-1,1))
))

y = truth(X)
w = int(np.sqrt(len(y)))
y = y.reshape((w,w))

# %%
c = plt.contour(y,[0])
contsegs = c.allsegs[0]

c_gt = [[cs[:,0]*dx+x0, cs[:,1]*dx+x0] for cs in contsegs]
# c_gt = [
#     contsegs[:,0]*dx+x0,
#     contsegs[:,1]*dx+x0
# ]

# %%
p = figure(
    x_range=[-1,1],
    y_range=[-1,1],
    match_aspect=True,
    plot_width=400,
    plot_height=400
)

color_mapper = LinearColorMapper(palette='Viridis256', low=-0.5, high=0.25)

p.image(
    image=[y],
    x=-1,
    y=-1,
    dw=2,
    dh=2,
    color_mapper = color_mapper
)

for c in c_gt:
    p.line(
        x=c[0],
        y=c[1],
        line_color="black",
        line_width=3
    )

show(p)
# Out:
#   <div class="bk-root" id="80a168b1-6852-48b2-9933-d972dc403e1d" data-root-id="59463"></div>

# %% [markdown]
# # Uniform Random

# %%
gpa_ur=skg.GaussianProcessRegressor(
    alpha=lam,
    kernel=kernel
)

n0 = 25
x0 = np.random.uniform(-1,1,(n0,1))
y0 = np.random.uniform(-1,1,(n0,1))

X = np.hstack((x0,y0))
y = np.array([truth([x]) for x in X]).reshape(-1,1)
# print(y)
gpa_ur.fit(X,y)
# Out:
# GaussianProcessRegressor(alpha=0.01, kernel=1**2 * RBF(length_scale=0.5))

# %%
p=viz_gpa(gpa_ur,thresh=False, contour=True)
p.circle(
    gpa_ur.X_train_[:,0],
    gpa_ur.X_train_[:,1],
    color="black"
)
show(p)
# Out:
#   <div class="bk-root" id="e409d2f8-c20d-4b7d-b1ba-94827d9e210b" data-root-id="36697"></div>

# %%
c_ur = viz_gpa(gpa_ur,thresh=False, contour=True, return_contour=True)

# %% [markdown]
# # Grid Search

# %%
gpa_gs=skg.GaussianProcessRegressor(
    alpha=lam,
    kernel=kernel
)

n0 = 400
nn = int(np.sqrt(n0))

xx = np.arange(0,2,2/nn)-1+1/nn
yy = np.arange(0,2,2/nn)-1+1/nn

x0,y0=np.meshgrid(xx,yy)
x0=x0.reshape([-1,1])
y0=y0.reshape([-1,1])

# x0 = np.random.uniform(-1,1,(n0,1))
# y0 = np.random.uniform(-1,1,(n0,1))

X = np.hstack((x0,y0))
y = np.array([truth([x]) for x in X]).reshape(-1,1)
# print(y)
gpa_gs.fit(X,y)
# Out:
# GaussianProcessRegressor(alpha=0.01, kernel=1**2 * RBF(length_scale=0.5))

# %%
p=viz_gpa(gpa_gs,thresh=False, contour=True)
p.circle(
    gpa_gs.X_train_[:,0],
    gpa_gs.X_train_[:,1],
    color="black"
)
show(p)
# Out:
#   <div class="bk-root" id="11e27fa7-574f-4806-ba87-53acef242095" data-root-id="60894"></div>

# %% [markdown]
# # Uncertainty Minimization

# %%
def gpa_next(gpa,x,y):

    n = gpa.X_train_.shape[1]
    g = skg.GaussianProcessRegressor(
        alpha=1e-6,
        kernel=kernel
    )
    g.fit(
        np.vstack((gpa.X_train_, np.array(x).reshape(-1,n))),
        np.vstack((gpa.y_train_, np.array(y).reshape(-1,1)))
    )
    # print(g.X_train_)
    return g

# %%
def p_err(mu,sig):
    return 0.5 - erf(np.abs(mu)/(np.sqrt(2)*sig))

# %%
# Given a pair (x,y) of "next" data, return the posterior intagrated Perr
def p_err_next(gpa,x,y):
    
    g = gpa_next(gpa,[x],y)
    
    x1range=[-1,1] # x position
    x2range=[-1,1] # y position
    dx = 0.05

    nx1 = int(np.diff(x1range)[0]/dx)
    nx2 = int(np.diff(x2range)[0]/dx)

    X1grid,X2grid = np.meshgrid(np.arange(*x1range,dx),np.arange(*x2range,dx))
    Xs = np.vstack([X1grid.ravel(), X2grid.ravel()]).transpose()

    mus, stds = g.predict(Xs, return_std=True)
    mus = mus[:,0]
    p_err_tp1 = np.sum(p_err(mus,stds))
    
    return p_err_tp1

# %%
# Given only a "next" x, assume the sampled y will land exactly on the mean and then return the posterior Perr
@jit
def infer_next(x,args):
    
    gpa = args
    
    n = gpa.X_train_.shape[1]
    yi = gpa.predict(x.reshape(-1,n))
    
    p_err_inf = p_err_next(gpa,x,yi)
    
    return p_err_inf

# %%
lam = 1e-2
l = 0.5
kernel = ConstantKernel(1.0, constant_value_bounds="fixed") * RBF(l, length_scale_bounds="fixed")
gpa_di = skg.GaussianProcessRegressor(
    alpha=lam,
    kernel=kernel
)

# Generate random initial data
n0 = 5
x0 = np.random.uniform(-1,1,(n0,1))
y0 = np.random.uniform(-1,1,(n0,1))

X = np.hstack((x0,y0))
y = np.array([truth([x]) for x in X]).reshape(-1,1)
gpa_di.fit(X,y)

bounds = [
    [-1,1],
    [-1,1]
]

N = 95
regret_di=[]
for i in tqdm(range(N)):
    
    opt = optimize.differential_evolution(
        infer_next,
        bounds,
        args=[gpa_di]
    )
    
    x_next = opt.x
    y_next = truth([x_next])
    
    gpa_di = gpa_next(gpa_di,x_next,y_next)
# Out:
# 100%|███████████████████████████████████████████| 95/95 [00:19<00:00,  4.97it/s]

# %%
p = viz_gpa(gpa_di,thresh=False, contour=True)
p.circle(
    gpa_di.X_train_[5:,0],
    gpa_di.X_train_[5:,1],
    color="black"
)
show(p)
# Out:
#   <div class="bk-root" id="3634e4b1-78e7-4639-b85b-d0b2486338d7" data-root-id="56404"></div>

# %%
c_di = viz_gpa(gpa_di,thresh=False, contour=True, return_contour=True)

# %% [markdown]
# # Comparison

# %%
c_ur = viz_gpa(gpa_ur,thresh=False, contour=True, return_contour=True)
c_gs = viz_gpa(gpa_gs,thresh=False, contour=True, return_contour=True)
c_di = viz_gpa(gpa_di,thresh=False, contour=True, return_contour=True)

# %%
p = figure(
    x_range=[-1,1],
    y_range=[-1,1],
    match_aspect=True,
    plot_width=400,
    plot_height=400
)

for c in c_gt:
    p.line(
        x=c[0],
        y=c[1],
        line_color="black",
        line_width=3
    )
    
for c in c_gs:
    p.line(
        x=c[0],
        y=c[1],
        line_color="red",
        line_width=3,
        legend_label="Grid Search"
    )
    
for c in c_di:
    p.line(
        x=c[0],
        y=c[1],
        line_color="blue",
        line_width=3,
        legend_label="Uncertainty Minimization"
    )

show(p)
# Out:
#   <div class="bk-root" id="0080768c-9a1b-4925-9b7d-fb6059446692" data-root-id="57954"></div>
