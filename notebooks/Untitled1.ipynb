# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
f0 = lambda th: np.sin(th)
f1 = lambda th: th

# %%
x = np.arange(-0.3,0.3,0.01)
v = lambda th1,th2: 0.01-np.abs((th1-th2)/th1)

# %%
plt.plot(x,f0(x),x,f1(x))

# %%
plt.plot(x,v(f0(x),f1(x)))
